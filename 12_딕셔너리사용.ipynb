# %%
# 딕셔너리 만들기

# 딕셔너리 = {
#     키1: 값1, 
#     키2: 값2, 
#     ...

# }

lux = {
    "health": 490, 
    "mana": 334, 
    "melee": 550, 
    "armor": 18.72
}

# %%
# 키 이름이 중복되면? 
lux = {
    "health": 490, 
    "health": 800,
    "mana": 334, 
    "melee": 550, 
    "armor": 18.72
}

print(lux)
# Out:
# {'health': 800, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 딕셔너리 1 자료형
x = {
    100: "hundred", 
    False: 0, 
    3.5: [3.5, 3.5]
}

print(x)
# Out:
# {100: 'hundred', False: 0, 3.5: [3.5, 3.5]}

# %%
x = {
    [10, 20] : 100
}

print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = {
#       2     [10, 20] : 100
#       3 }
#       5 print(x)
#
# TypeError: unhashable type: 'list'

# %%
# 빈 딕셔너리 만들기

x = {}
y = dict()

print(x)
print(y)

print(type(x))
print(type(y))
# Out:
# {}
# {}
# <class 'dict'>
# <class 'dict'>

# %%
# dict로 딕셔너리 만들기 
lux1 = dict(
    health=490, 
    mana=334,
    melee=550, 
    armor=18.72
)

lux1
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux2 = dict(zip(
    ['health', 'mana', 'melee', 'armor'], 
    [490, 334, 550, 18.72]
))

print(lux2)
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux3 = dict([
    ('health', 490),
    ('mana', 334),
    ('melee', 550),
    ('armor', 18.72)
])
lux3
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux4 = dict({'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72})
lux4
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 딕셔널의 키에 접근하고 값 할당하기 
lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

lux['health']
lux["armor"]
# Out:
# 18.72

# %%
lux["health"] = 2037
lux["mana"] = 1104

lux
# Out:
# {'health': 2037, 'mana': 1104, 'melee': 550, 'armor': 18.72}

# %%
lux['mana_regen'] = 3.28
lux
# Out:
# {'health': 2037,
#  'mana': 1104,
#  'melee': 550,
#  'armor': 18.72,
#  'mana_regen': 3.28}

# %%
lux["attack_speed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 lux["attack_speed"]
#
# KeyError: 'attack_speed'

# %%
lux.get("attack_speed", )

# %%
# 딕셔너리에 키가 있는지 확인하기 
lux
# Out:
# {'health': 2037,
#  'mana': 1104,
#  'melee': 550,
#  'armor': 18.72,
#  'mana_regen': 3.28}

# %%
'health' in lux
# Out:
# True

# %%
2037 in lux
# Out:
# False

# %%
# 딕셔너리 키 개수 구하기 
lux
# Out:
# {'health': 2037,
#  'mana': 1104,
#  'melee': 550,
#  'armor': 18.72,
#  'mana_regen': 3.28}

# %%
len(lux)
# Out:
# 5
