# %%
# 재귀호출 사용하기

def hello():
    print("Hello world!")
    hello()

# %%
hello()

# %%
## 재귀호출에 종료 조건 만들기

def hello(count):
    if count == 0:
        return 

    print("Hello, World!", count)

    count -= 1
    hello(count)

# %%
hello(5)
# Out:
# Hello, World! 5
# Hello, World! 4
# Hello, World! 3
# Hello, World! 2
# Hello, World! 1

# %%
# 재귀호출로 팩토리얼 구하기 

def factorial(n):
    if n == 1:
        return 1
    
    return n * factorial(n - 1)
           5 * factorial(4)
               4 *

# %%
print(factorial(5))
# Out:
# 120
