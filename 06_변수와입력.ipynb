# %%
a, b = map(int, input("숫자 두 개를 입력하세요").split())

# %%
print(a + b)
# Out:
# 40

# %%
input().split()
# Out:
# ['-10', '20', '30']

# %%
a, b, c = ['-10', '20', '30']
print(a)
print(b)
print(c)
print(a+b+c)
# Out:
# -10
# 20
# 30
# -102030

# %%
a, b, c = map(int, input().split())
print( a + b + c)
# Out:
# 40
